# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("link_prediction.csv")

# %%
df
# Out:
#    summerize     embed      dim       auc
# 0     kobart    kobart  Default  0.859511
# 1     kobart    kobart       64  0.888172
# 2     kobart    kobart       32  0.885305
# 3     kobart    kobart        8  0.891331
# 4     kobart     tfidf  Default  0.766775
# 5     kobart     tfidf       64  0.884178
# 6     kobart     tfidf       32  0.888639
# 7     kobart     tfidf        8  0.890360
# 8     kobart  word2vec  Default  0.884023
# 9     kobart  word2vec       64  0.885139
# 10    kobart  word2vec       32  0.888530
# 11    kobart  word2vec        8  0.891462
# 12   lexrank    kobart  Default  0.870404
# 13   lexrank    kobart       64  0.889574
# 14   lexrank    kobart       32  0.891384
# 15   lexrank    kobart        8  0.894451
# 16   lexrank     tfidf  Default  0.783298
# 17   lexrank     tfidf       64  0.888188
# 18   lexrank     tfidf       32  0.882683
# 19   lexrank     tfidf        8  0.890333
# 20   lexrank  word2vec  Default  0.884649
# ...

# %%
df['method'] = df.summerize+'_'+df.embed

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))
plt.ylim(0.8, 1.0)

sns.barplot(data=df, x='method', y='auc', hue='dim')
# Out:
# <AxesSubplot:xlabel='method', ylabel='auc'>

# %%
plt.ylim(0.8, 1.0)
sns.barplot(data=df, x='summerize', y='auc', hue='dim')
# Out:
# <AxesSubplot:xlabel='summerize', ylabel='auc'>

# %%
plt.ylim(0.8, 1.0)
sns.barplot(data=df, x='embed', y='auc', hue='dim')
# Out:
# <AxesSubplot:xlabel='embed', ylabel='auc'>

# %%
df = pd.read_csv("link_regression.csv")

# %%
df['method'] = df.summarize+'_'+df.embed

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))
# plt.ylim(0.8, 1.0)

sns.barplot(data=df, x='method', y='rmse', hue='dim')
# Out:
# <AxesSubplot:xlabel='method', ylabel='rmse'>

# %%
sns.barplot(data=df, x='summarize', y='rmse', hue='dim')
# Out:
# <AxesSubplot:xlabel='summarize', ylabel='rmse'>

# %%
sns.barplot(data=df, x='embed', y='rmse', hue='dim')
# Out:
# <AxesSubplot:xlabel='embed', ylabel='rmse'>
